# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import Dataset

# %%
url = 'https://raw.githubusercontent.com/aaneloy/DATA2010-Fall2021-Lab/main/Dataset/house_data.csv'

house_data_1 = pd.read_csv(url, index_col=0, parse_dates=[0])
house_data_1
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
house_data_1.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
url = 'https://raw.githubusercontent.com/aaneloy/DATA2010-Fall2021-Lab/main/Dataset/house_data.csv'

house_data = pd.read_csv(url, header=0)
house_data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# # Analysing the Data

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
house_data.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# # **Removing unecessary features**

# %%
house_data.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
house_data = house_data.drop(['id','waterfront', 'view','date'], axis= 1)

# %%
house_data
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %% [markdown]
# # Exploratory Data Analysis - Visualizations

# %%
plt.figure(figsize = (13,13))

sns.heatmap(house_data.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='sqft_living', y= 'price', data = house_data)
plt.title("Linear model between Feature 'sqft_living' and dependent variable 'price'\n")
# Out:
# Text(0.5, 1.0, "Linear model between Feature 'sqft_living' and dependent variable 'price'\n")

# %%
sns.regplot(x='sqft_above', y= 'price', data = house_data, color = 'green')
plt.title("Linear model between Feature 'sqft_living' and dependent variable 'price'\n")
# Out:
# Text(0.5, 1.0, "Linear model between Feature 'sqft_living' and dependent variable 'price'\n")

# %%
import pickle

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected= True)

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
# ...

# %%
house_data['yr_built'].iplot(kind = 'hist')
# Out:
# <div>                            <div id="983e56c3-40c8-4932-9ea9-a807c327f222" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
house_data['price'].iplot(kind = 'hist')
# Out:
# <div>                            <div id="dabc388c-38b0-4195-8277-b01e2b0601f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize = (8,5))

sns.countplot(data = house_data, x = 'bedrooms', palette = 'rainbow')
plt.title("Countplot of No of Bedrooms")

#plt.tight_layout()
#plt.savefig("countplot")
# Out:
# Text(0.5, 1.0, 'Countplot of No of Bedrooms')

# %%
sns.barplot(x = 'condition', y = 'price', data = house_data)
plt.title("Barplot of Condition VS Price\n")
# Out:
# Text(0.5, 1.0, 'Barplot of Condition VS Price\n')

# %% [markdown]
# # Spliting Dataset

# %%
house_data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
X = house_data[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'condition', 'grade', 'sqft_above', 'sqft_basement',
       'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15']]
y = house_data['price']

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  grade  \
# 0             3       1.00         1180      5650     1.0          3      7
# 1             3       2.25         2570      7242     2.0          3      7
# 2             2       1.00          770     10000     1.0          3      6
# 3             4       3.00         1960      5000     1.0          5      7
# 4             3       2.00         1680      8080     1.0          3      8
# ...         ...        ...          ...       ...     ...        ...    ...
# 21608         3       2.50         1530      1131     3.0          3      8
# 21609         4       2.50         2310      5813     2.0          3      8
# 21610         2       0.75         1020      1350     2.0          3      7
# 21611         3       2.50         1600      2388     2.0          3      8
# 21612         2       0.75         1020      1076     2.0          3      7
#
# ...

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, test_size = 0.3, random_state=1234)

# %% [markdown]
# # SUPERVISED LEARNING ALGORITHM - REGRESSION

# %%
lm = LinearRegression()

# %%
Xtrain
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  grade  \
# 15026         2       1.75         1620    113862     1.5          3      7
# 7354          3       1.00         1400     10800     1.0          3      6
# 6051          2       1.00         1460      6000     1.0          2      7
# 4398          4       1.75         1620     10530     1.0          3      7
# 9298          3       2.50         2030    217805     1.0          3      9
# ...         ...        ...          ...       ...     ...        ...    ...
# 8222          3       2.25         3360      7108     2.0          3     10
# 9449          4       3.00         3600      9687     2.0          4      9
# 8471          3       2.75         1710      9448     1.0          3      7
# 17048         3       1.00         1050      6240     1.0          5      5
# 1318          3       1.75         1650      8073     1.0          3      7
#
# ...

# %%
ytrain
# Out:
# 15026     439000.0
# 7354      279900.0
# 6051      312000.0
# 4398      249950.0
# 9298      565000.0
#            ...
# 8222     2193000.0
# 9449     1698000.0
# 8471      515000.0
# 17048     208000.0
# 1318      234975.0
# Name: price, Length: 15129, dtype: float64

# %%
lm.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
y_prediction = lm.predict(Xtest)
y_prediction
# Out:
# array([ 522675.91354182,  561646.95162362, 1034384.18089665, ...,
#         457258.46364053,  622859.39407819,  451607.28517192])

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df_results = pd.DataFrame({'Actual': ytest, 'Predicted': y_prediction})
df_results['Residuals'] = abs(df_results['Actual']) - abs(df_results['Predicted'])
df_results
# Out:
#            Actual   Predicted   Residuals
# 12432  485000.000  522675.914  -37675.914
# 7793   358000.000  561646.952 -203646.952
# 13435  716500.000 1034384.181 -317884.181
# 1821   367500.000  400891.477  -33391.477
# 12449  544000.000  450815.428   93184.572
# ...           ...         ...         ...
# 2596  1065000.000  607378.678  457621.322
# 21161  459990.000  488209.540  -28219.540
# 20133  388500.000  457258.464  -68758.464
# 11130  530000.000  622859.394  -92859.394
# 16762  449400.000  451607.285   -2207.285
#
# [6484 rows x 3 columns]

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

print('MSE', metrics.mean_squared_error(ytest, y_prediction))
print('RMSE', np.sqrt(metrics.mean_squared_error(ytest, y_prediction)))
print('Accuracy', "{:.0%}".format(metrics.explained_variance_score(ytest, y_prediction)))
print('R2:', r2_score(ytest, y_prediction))
# Out:
# MSE 43735059279.692986
# RMSE 209129.28843108748
# Accuracy 66%
# R2: 0.6633128794074246

# %%
plt.figure(figsize=(12,5))

sns.regplot(ytest,y_prediction,house_data,color='purple')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Linear Regression Curve")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Linear Regression Curve')

# %% [markdown]
# # Improving the Prediction
#
# <br/>Few well known steps:<br/>
#     1. **Remove Outliers**<br />
#     2. **Scale the data**<br />
#     3. **Reduce unwanted Features** <br/>

# %% [markdown]
# ## 1. Removing Outliers

# %%
df = house_data.copy()

# %%
from scipy import stats

def drop_numerical_outliers(df, z_thresh=3):
    # Constrains will contain `True` or `False` depending on if it is a value below the threshold.
    constrains = df.select_dtypes(include=[np.number]).apply(lambda x: np.abs(stats.zscore(x)) < z_thresh).all(axis=1)
    # Drop (inplace) values set to be rejected
    df.drop(df.index[~constrains], inplace=True)
    
drop_numerical_outliers(df)
df
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     221900.000         3      1.000         1180      5650   1.000
# 2     180000.000         2      1.000          770     10000   1.000
# 3     604000.000         4      3.000         1960      5000   1.000
# 4     510000.000         3      2.000         1680      8080   1.000
# 6     257500.000         3      2.250         1715      6819   2.000
# ...          ...       ...        ...          ...       ...     ...
# 21608 360000.000         3      2.500         1530      1131   3.000
# 21609 400000.000         4      2.500         2310      5813   2.000
# 21610 402101.000         2      0.750         1020      1350   2.000
# 21611 400000.000         3      2.500         1600      2388   2.000
# 21612 325000.000         2      0.750         1020      1076   2.000
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
sns.regplot(x='sqft_living', y= 'price', data = df)
plt.title("Linear model between Feature 'sqft_living' and dependent variable 'price'\n")
# Out:
# Text(0.5, 1.0, "Linear model between Feature 'sqft_living' and dependent variable 'price'\n")

# %%
sns.regplot(x='sqft_above', y= 'price', data = df, color = 'green')
plt.title("Linear model between Feature 'sqft_living' and dependent variable 'price'\n")
# Out:
# Text(0.5, 1.0, "Linear model between Feature 'sqft_living' and dependent variable 'price'\n")

# %%
X = df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'condition', 'grade', 'sqft_above', 'sqft_basement',
       'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15']]
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state=1234)

# %%
lm_2 = LinearRegression()
lm_2.fit(X_train,y_train)
y_predicted=lm_2.predict(X_test)

# %%
df_results_2 = pd.DataFrame({'Actual': y_test, 'Predicted': y_predicted})
df_results_2['Residuals'] = abs(df_results_2['Actual']) - abs(df_results_2['Predicted'])
df_results_2
# Out:
#           Actual  Predicted   Residuals
# 20220 204000.000 188745.249   15254.751
# 6893  900000.000 826326.714   73673.286
# 14711 352500.000 383775.560  -31275.560
# 21249 494000.000 660109.591 -166109.591
# 11996 315000.000 235973.214   79026.786
# ...          ...        ...         ...
# 13057 110000.000 128679.319  -18679.319
# 16494 595000.000 503079.024   91920.976
# 12603 470950.000 653493.537 -182543.537
# 20368 805000.000 674968.702  130031.298
# 6506  557500.000 538312.725   19187.275
#
# [5755 rows x 3 columns]

# %%
print('MSE', metrics.mean_squared_error(y_test, y_predicted))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test, y_predicted)))
print('Accuracy', "{:.0%}".format(metrics.explained_variance_score(y_test, y_predicted)))
print('R2:', r2_score(y_test,y_predicted))
# Out:
# MSE 17631133886.43196
# RMSE 132782.28001669486
# Accuracy 68%
# R2: 0.6799187390378196

# %%
plt.figure(figsize=(12,5))

sns.regplot(y_test,y_predicted,df,color='green')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Linear Regression Curve")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Linear Regression Curve')

# %% [markdown]
# ## 2. Scale the Data

# %%
col_list = list(df.columns.values)
col_list
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df_train = df.copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_train[col_list] = scaler.fit_transform(df_train[col_list])

# %%
df_train
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0     -1.113    -0.384     -1.515       -1.053    -0.370  -0.891     -0.656
# 2     -1.287    -1.560     -1.515       -1.603     0.009  -0.891     -0.656
# 3      0.477     0.792      1.380       -0.007    -0.427  -0.891      2.426
# 4      0.086    -0.384     -0.068       -0.382    -0.158  -0.891     -0.656
# 6     -0.965    -0.384      0.294       -0.335    -0.268   0.958     -0.656
# ...      ...       ...        ...          ...       ...     ...        ...
# 21608 -0.538    -0.384      0.656       -0.583    -0.764   2.806     -0.656
# 21609 -0.372     0.792      0.656        0.463    -0.356   0.958     -0.656
# 21610 -0.363    -1.560     -1.877       -1.268    -0.745   0.958     -0.656
# 21611 -0.372    -0.384      0.656       -0.490    -0.655   0.958     -0.656
# 21612 -0.684    -1.560     -1.877       -1.268    -0.769   0.958     -0.656
#
# ...

# %%
sns.regplot(x='sqft_living', y= 'price', data =df_train)
plt.title("Linear model between Feature 'sqft_living' and dependent variable 'price'\n")
# Out:
# Text(0.5, 1.0, "Linear model between Feature 'sqft_living' and dependent variable 'price'\n")

# %%
X=df_train[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built','yr_renovated',
       'sqft_living15', 'sqft_lot15']]
y=df_train['price']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=1234)

# %%
lm_3 = LinearRegression()
lm_3.fit(X_train,y_train)
y_predicted_2 = lm_3.predict(X_test)

# %%
df_results_3 = pd.DataFrame({'Actual': y_test, 'Predicted': y_predicted_2})
df_results_3['Residuals'] = abs(df_results_3['Actual']) - abs(df_results_3['Predicted'])
df_results_3
# Out:
#        Actual  Predicted  Residuals
# 20220  -1.187     -0.902      0.285
# 6893    1.708      1.482      0.226
# 14711  -0.569     -0.338      0.232
# 21249   0.019      0.079     -0.060
# 11996  -0.725     -0.938     -0.213
# ...       ...        ...        ...
# 13057  -1.578     -1.337      0.241
# 16494   0.439     -0.384      0.055
# 12603  -0.077      0.386     -0.309
# 20368   1.313      0.854      0.458
# 6506    0.283      0.530     -0.247
#
# [5755 rows x 3 columns]

# %%
print('MSE', metrics.mean_squared_error(y_test, y_predicted_2))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test, y_predicted_2)))
print('Accuracy', "{:.0%}".format(metrics.explained_variance_score(y_test, y_predicted_2)))
print('R2:', r2_score(y_test,y_predicted_2))
# Out:
# MSE 0.39383029796582386
# RMSE 0.6275589995895396
# Accuracy 59%
# R2: 0.5867481596282973

# %%
plt.figure(figsize=(12,5))

sns.regplot(y_test,y_predicted_2,df_train,color='red')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Linear Regression Curve")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Linear Regression Curve')

# %% [markdown]
# ## 3. Reduce feature(or Feature Importance) using Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV


X=df[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built','yr_renovated',
       'sqft_living15', 'sqft_lot15']]
y=df['price']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3, random_state=1234)
#rfr = RandomForestRegressor(n_estimators = 300, max_depth = 5, min_samples_leaf= 5, max_features = 'sqrt')
rfr = RandomForestRegressor()


rfr.fit(X_train, y_train) # gets the parameters for the rfr model

rfr_cv = cross_val_score(rfr,X_train, y_train, cv = 5, scoring = 'r2')
print("R2: ", rfr_cv.mean())
# Out:
# R2:  0.6730926120650731

# %%
importance = rfr.feature_importances_

# map feature importance values to the features
feature_importances = zip(importance, X_train.columns)
#list(feature_importances)

sorted_feature_importances = sorted(feature_importances, reverse = True)
#print(sorted_feature_importances)

top_10_predictors = sorted_feature_importances[0:10]
values = [value for value, predictors in top_10_predictors]
predictors = [predictors for value, predictors in top_10_predictors]
print(predictors)

plt.rcParams['figure.figsize'] = [15, 10]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances RF")
plt.bar(range(len(predictors)), values,color="r", align="center");
plt.xticks(range(len(predictors)), predictors, rotation=90);
plt.show()
# Out:
# ['grade', 'yr_built', 'sqft_living', 'sqft_living15', 'sqft_lot15', 'sqft_lot', 'sqft_above', 'bathrooms', 'sqft_basement', 'bedrooms']

# %%
y_pred_RF = rfr.predict(X_test)

# %%
df_results_rf = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_RF})
df_results_rf['Residuals'] = abs(df_results_rf['Actual']) - abs(df_results_rf['Predicted'])
df_results_rf
# Out:
#           Actual   Predicted   Residuals
# 20220 204000.000  268420.307  -64420.307
# 6893  900000.000 1065448.880 -165448.880
# 14711 352500.000  397953.550  -45453.550
# 21249 494000.000  422965.962   71034.038
# 11996 315000.000  273902.750   41097.250
# ...          ...         ...         ...
# 13057 110000.000  232793.760 -122793.760
# 16494 595000.000  445877.030  149122.970
# 12603 470950.000  562094.900  -91144.900
# 20368 805000.000  790022.500   14977.500
# 6506  557500.000  663034.000 -105534.000
#
# [5755 rows x 3 columns]

# %%
plt.figure(figsize=(12,5))

sns.regplot(y_test,y_pred_RF,df,color='blue')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Random Forest Curve")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Random Forest Curve')

# %% [markdown]
# # Now try bunch of other models <br/>
#
# Regression:<br/>
# * DecisionTreeRegressor <br/>
#
# Clustering:
# * K-means <br/>
#
# Classification:<br/>
# * Logistic Regression <br/>

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans

# %% [markdown]
# ## 1. DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)

dtr_cv = cross_val_score(dtr,X_train, y_train, cv = 5, scoring = 'r2')
print("R2: ", dtr_cv.mean())


y_pred_dtr = dtr.predict(X_test)

df_results_dtr = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_dtr})
df_results_dtr['Residuals'] = abs(df_results_dtr['Actual']) - abs(df_results_dtr['Predicted'])

df_results_dtr
# Out:
# R2:  0.37048832292966394
#           Actual   Predicted   Residuals
# 20220 204000.000  350000.000 -146000.000
# 6893  900000.000 1145000.000 -245000.000
# 14711 352500.000  434466.000  -81966.000
# 21249 494000.000  515000.000  -21000.000
# 11996 315000.000  230000.000   85000.000
# ...          ...         ...         ...
# 13057 110000.000  244900.000 -134900.000
# 16494 595000.000  575000.000   20000.000
# 12603 470950.000  495000.000  -24050.000
# 20368 805000.000  677000.000  128000.000
# 6506  557500.000  700500.000 -143000.000
#
# [5755 rows x 3 columns]

# %%
plt.figure(figsize=(12,5))

sns.regplot(y_test,y_pred_dtr,df,color='blue')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("DTR Curve")
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'DTR Curve')

# %% [markdown]
# ## 4. K-means

# %%
km = KMeans(n_clusters=3)

km.fit(house_data.drop(['price'],axis=1))
# Out:
# KMeans(n_clusters=3)

# %%
km.cluster_centers_
# Out:
# array([[ 3.37088159e+00,  2.10742141e+00,  2.06343177e+03,
#          1.04613217e+04,  1.49300402e+00,  3.41172300e+00,
#          7.64448121e+00,  1.77175462e+03,  2.91677145e+02,
#          1.97075344e+03,  8.43446939e+01,  9.80786919e+04,
#          4.75617471e+01, -1.22217831e+02,  1.97729695e+03,
#          9.73114044e+03],
#        [ 3.37471783e+00,  2.44413093e+00,  2.82891648e+03,
#          2.06257002e+05,  1.54853273e+00,  3.30248307e+00,
#          8.20541761e+00,  2.54220090e+03,  2.86715576e+02,
#          1.98265011e+03,  9.00090293e+01,  9.80433837e+04,
#          4.74818799e+01, -1.22032393e+02,  2.42363883e+03,
#          1.48904016e+05],
#        [ 3.20000000e+00,  2.73333333e+00,  3.18426667e+03,
#          9.21718533e+05,  1.73333333e+00,  3.33333333e+00,
#          8.93333333e+00,  2.98826667e+03,  1.96000000e+02,
#          1.98206667e+03,  1.42108547e-14,  9.80378000e+04,
#          4.74788467e+01, -1.22025733e+02,  2.13133333e+03,
#          2.75858467e+05]])

# %%
c = house_data.drop(['price',],axis=1)

plt.scatter(c.iloc[:, 0], c.iloc[:, 1], s=50)
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], c='black', s=200, alpha=0.5)

# %%
from sklearn.manifold import TSNE

tsn = TSNE(random_state=20)
res_tsne = tsn.fit_transform(house_data)

plt.figure(figsize=(8,8))
sns.scatterplot(res_tsne[:,0],res_tsne[:,1]);
# Out:
# D:\Anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# D:\Anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## 3. Logistic Regression

# %%
df['price'].mean()
# Out:
# 489387.430745973

# %%
def cluster_vals (cost):
    if cost > 489387.430745973:
        return 1
    else:
        return 0
df['Cluster'] = df['price'].apply(cluster_vals)

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 0 221900.000         3      1.000         1180      5650   1.000          3
# 2 180000.000         2      1.000          770     10000   1.000          3
# 3 604000.000         4      3.000         1960      5000   1.000          5
# 4 510000.000         3      2.000         1680      8080   1.000          3
# 6 257500.000         3      2.250         1715      6819   2.000          3
#
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode    lat  \
# 0      7        1180              0      1955             0    98178 47.511
# 2      6         770              0      1933             0    98028 47.738
# 3      7        1050            910      1965             0    98136 47.521
# 4      8        1680              0      1987             0    98074 47.617
# 6      7        1715              0      1995             0    98003 47.310
#
#       long  sqft_living15  sqft_lot15  Cluster
# ...

# %%
plt.figure(figsize=(12,5))

df[df['Cluster']==0]['sqft_living'].hist(alpha=0.5,bins=30,label='Lower than Average Price',color='red')
df[df['Cluster']==1]['sqft_living'].hist(alpha=0.5,bins=30,label='Higher than Average Price',color='blue')

plt.legend()
plt.xlabel('Square Feet of Living Area')
plt.title("Histogram Of Living Area In Square Feet Based On Mean Price")
# Out:
# Text(0.5, 1.0, 'Histogram Of Living Area In Square Feet Based On Mean Price')

# %%
y = df['Cluster']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1234)

lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = lr.predict(X_test)

df_results = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})
df_results
# Out:
#        Actual  Predicted
# 20220       0          0
# 6893        1          1
# 14711       0          0
# 21249       1          1
# 11996       0          0
# ...       ...        ...
# 13057       0          0
# 16494       1          0
# 12603       0          1
# 20368       1          1
# 6506        1          1
#
# [5755 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("\nClassification Report:\n",classification_report(y_test,predictions))
print("\nConfusion Matrix: \n",confusion_matrix(y_test,predictions))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      3420
#            1       0.75      0.65      0.70      2335
#
#     accuracy                           0.77      5755
#    macro avg       0.77      0.75      0.76      5755
# weighted avg       0.77      0.77      0.77      5755
#
#
# Confusion Matrix:
#  [[2927  493]
#  [ 816 1519]]
